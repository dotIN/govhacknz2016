# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import bokeh
from bokeh.charts import Line, Bar
from bokeh.plotting import show, output_file, figure
from bokeh.charts import Chart, Line
import numpy as np

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
all_data = pd.DataFrame.from_csv('Mean Rents by TA.csv', index_col=None,parse_dates = ['Month'])
all_data.head
# Out:
# <bound method NDFrame.head of          Month  Ashburton District  Auckland  Buller District  \
# 0   1993-01-01                 112       200             92.0
# 1   1993-02-01                  98       205             83.0
# 2   1993-03-01                 106       199             89.0
# 3   1993-04-01                 117       201             89.0
# 4   1993-05-01                 125       210             78.0
# 5   1993-06-01                  97       202             98.0
# 6   1993-07-01                 127       213             93.0
# 7   1993-08-01                 118       208             94.0
# 8   1993-09-01                 115       212             66.0
# 9   1993-10-01                 114       213             95.0
# 10  1993-11-01                 111       204             94.0
# 11  1993-12-01                 113       218            107.0
# 12  1994-01-01                 125       215             79.0
# 13  1994-02-01                 102       215             87.0
# ...

# %%
all_data.columns
# Out:
# Index(['Month', 'Ashburton District', 'Auckland', 'Buller District',
#        'Carterton District', 'Central Hawkes Bay District',
#        'Central Otago District', 'Christchurch', 'Clutha District', 'Dunedin',
#        'Far North District', 'Franklin District', 'Gisborne District',
#        'Gore District', 'Grey District', 'Hamilton', 'Hastings District',
#        'Hauraki District', 'Horowhenua District', 'Hurunui District',
#        'Invercargill', 'Kaikoura District', 'Kaipara District',
#        'Kapiti Coast District', 'Kawerau District', 'Lower Hutt',
#        'Mackenzie District', 'Manawatu District', 'Manukau',
#        'Marlborough District', 'Masterton District', 'Matamata-Piako District',
#        'Napier', 'National Total', 'Nelson', 'New Plymouth District',
#        'North Shore', 'Opotiki District', 'Otorohanga District',
#        'Palmerston North', 'Papakura District', 'Porirua',
#        'Queenstown-Lakes District', 'Rangitikei District', 'Rodney District',
# ...

# %%
# %%HTML
# <head>Hi</head>
# Out:
# <head>Hi</head>

# %%
#all_data.date_range('2000','2010',freq='Y')
#ts = all_data.Series(index=all_data.)
data_210 = all_data[['Month','Wellington','Marlborough District','Upper Hutt','Porirua','Kapiti Coast District','South Wairarapa District','Lower Hutt']]
data_210
data_2010 = data_210[(all_data.Month.dt.year > 2000) & (all_data.Month.dt.year < 2010)]
# output to static HTML file
output_file("welly.html")
welly = data_2010.set_index('Month')
#welly.plot()
chart = Line(welly,xlabel='Year', ylabel='Rent')
show(chart)
# For Past one Year
#current_year = data_210[(data_210.Month.dt.year >=2015) & (data_210.Month.dt.year <= 2016)]
#current_year.set_index('Month').plot()
#chart = Line(current_year.set_index('Month'),xlabel='Year', ylabel='Rent')
#bokeh.io.show(chart)
#data_2010 = data_210[(data_210.Month.dt.year > 2000) & (data_210.Month.dt.year < 2010)]
#print("Mean across",data_2010.mean())
#data_2010[['Wellington','Marlborough District','Upper Hutt','Porirua','Kapiti Coast District','South Wairarapa District','Lower Hutt']].mean().plot()
#data_2010[['Wellington','Marlborough District','Upper Hutt','Porirua','Kapiti Coast District','South Wairarapa District','Lower Hutt']]
#data_2010 = all_data[all_data.Month.dt.to_period(start='2000',end='2010',freq='Y')]
#data_2010.Month.dt.period_range(start='2000',end='2010',freq='Y')
#data_2010.set_index('Month').plot()
#data_2010['National Total'].sum()

# %%
cch = all_data[['Month','Waimakariri District','Kaikoura District','Hurunui District','Selwyn District','Ashburton District','Mackenzie District','Waitaki District','Waimate District']]
cch_2010 = cch[(all_data.Month.dt.year > 2000) & (all_data.Month.dt.year < 2010)]
cch1_2010
cch_2010.set_index('Month').plot()

# %%
import numpy as np
from bokeh.plotting import figure, output_file, show
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")

TOOLS="resize,pan,wheel_zoom,box_zoom,reset,hover"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)

# %%
#print(bokeh.__version__)
TOOLS="resize,pan,wheel_zoom,box_zoom,reset,hover"
cch1 = all_data[['Month','Waimakariri District','Kaikoura District','Hurunui District','Selwyn District','Ashburton District','Mackenzie District','Waitaki District','Waimate District']]
cch2 = all_data[['Waimakariri District','Kaikoura District','Hurunui District','Selwyn District','Ashburton District','Mackenzie District','Waitaki District','Waimate District']]
cch1_2010 = cch1[(all_data.Month.dt.year > 2000) & (all_data.Month.dt.year < 2010)]
#cch2 = cch2.dropna
#cch1_2011 = cch1_2010.dropna
#print(cch1_2010)
#chart = Line(cch1_2010.set_index('Month'),xlabel='Year', ylabel='Rent')
#output_file("christhurch.html", title="ChristChurch Regional Council By Year")
#bokeh.io.show(chart)
#show(chart)
# output to static HTML file
output_file("cch.html")
# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_axis_label='Year', y_axis_label='Rent')
#cch1_2010.set_index('Month').plot()
p.line(cch1_2010.set_index('Month'))
# show the results
bokeh.io.show(p)

# %%
national =all_data[['National Total','Month']] 
nat_index = national.set_index(['National Total','Month'])
nat_index.unstack('Month')
#nat_index.unstack('Month')
#avg_all = national[(all_data.Month.str.contains('2015')) & (all_data.Month.str.contains('2014'))]

#avg_all.asfreq
#national =all_data['National Total'].value_counts()
#national
#avg_all.value_counts().sort_index().plot()
# Out:
# Empty DataFrame
# Columns: []
# Index: [157, 160, 161, 162, 165, 167, 168, 170, 171, 173, 174, 175, 177, 179, 181, 182, 184, 186, 188, 190, 194, 198, 199, 200, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 219, 220, 221, 222, 224, 226, 227, 228, 229, 230, 231, 233, 238, 243, 245, 246, 247, 251, 252, 253, 255, 259, 260, 261, 263, 266, 267, 269, 271, 273, 274, 277, 278, 279, 280, 281, 282, 284, 287, 289, 295, 296, 297, 299, 300, 301, 304, 307, 309, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, ...]
#
# [151 rows x 0 columns]

# %%
all_data[['National Total','Wellington','Auckland','Month','Christchurch']].plot()

# %%
dfsum = all_data.groupby('Month', as_index=False).sum()
dfsum['Year'] = 'All'
dfsum.head
# Out:
# <bound method NDFrame.head of           Month  Ashburton District  Auckland  Buller District  \
# 0    1993-01-01                 112       200             92.0
# 1    1993-02-01                  98       205             83.0
# 2    1993-03-01                 106       199             89.0
# 3    1993-04-01                 117       201             89.0
# 4    1993-05-01                 125       210             78.0
# 5    1993-06-01                  97       202             98.0
# 6    1993-07-01                 127       213             93.0
# 7    1993-08-01                 118       208             94.0
# 8    1993-09-01                 115       212             66.0
# 9    1993-10-01                 114       213             95.0
# 10   1993-11-01                 111       204             94.0
# 11   1993-12-01                 113       218            107.0
# 12   1994-01-01                 125       215             79.0
# ...

# %%
detailed = pd.read_csv("detailed.csv", index_col="SAU")
row = detailed[detailed.Property_Type == "Property Type Total"].loc[:, "Bedrooms":]
row = row[row.Bedrooms == "2"].loc[:, "1993-03-01":]
row_t = row.T
row_t.index = row_t.index.map(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d").date())
row_t.iloc[:, 46:51].interpolate().plot()
sau_codes = pd.read_csv("WellingtonDetailsMeanRentsWithCoordinates.csv")
#sau_codes.columns
unique_saus = sau_codes[['Unnamed: 1', 'SAU']].drop_duplicates()
detailed.reset_index
detailed.index
#unique_saus[unique_saus.SAU]
# Out:
# /Users/raghav/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index([          500100,           500100,           500100,           500100,
#                  500100,           500100,           500202,           500202,
#                  500202,           500202,
#        ...
#        'National Total', 'National Total', 'National Total', 'National Total',
#        'National Total', 'National Total', 'National Total', 'National Total',
#        'National Total', 'National Total'],
#       dtype='object', name='SAU', length=20845)

# %%
# Replace SAU with Name with map function, below for loop is to check if gven SAU exists in the map file
detailed_tmp = pd.read_csv("detailed.csv")
for i, row in detailed_tmp.iterrows():
    if row['SAU'] in unique_saus['SAU']:
        print(type(unique_saus['SAU']))
    else:
        print("Not Found")
                

#detailed_tmp.SAU.map(lambda x: unique_saus[x])
#unique_saus.head
# Out:
# /Users/raghav/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# Not Found
# ...

# %%
all_crimes = pd.read_csv("crimestats.csv",parse_dates = ['Year or Month'],usecols=['Location', 'Scene', 'Offence', 'Year or Month', 'Measure', 'Value'])
Canterbury = all_crimes[(all_crimes['Location'] == 'Canterbury District') & (all_crimes['Measure'] == 'Recorded')]
#Canterbury[(all_crimes['Offence'] == 'Theft and related offences') & (all_crimes['Offence'] == 'Total Offences') & (all_crimes['Offence'] == 'Unlawful entry with intent/burglary, break and enter'])]
#Canterbury.groupby(['Offence']).count()
Welly = all_crimes[(all_crimes['Location'] == 'Wellington District')]
#print(Welly.Offence.value_counts(ascending=False).head(5))
print(Welly.Offence.value_counts())
chart = Bar(Welly.Offence.value_counts(ascending=False).head(5),xlabel='Area', ylabel='Crimes')
#bokeh.io.show(chart)
national = all_crimes[(all_crimes['Location'] == 'Total New Zealand') & (all_crimes['Measure'] == 'Recorded')]
#Welly.groupby(['Offence']).count()
# Get All Offences based on year
#all_crimes.groupby(['Offence','Year or Month']).mean()
#all_crimes.groupby(['Offence','Location']).size()
#print(all_crimes.Location.groupby(all_crimes['Offence']))
#all_crimes['Location'].groupby(all_crimes['Offence']).describe()
#list(by_group)
#all_crimes.head
# Get Homicide across NZ
#all_crimes[(all_crimes['Offence'] == 'Homicide and related offences') & (all_crimes['Location'] == 'Total New Zealand')]
# Out:
# Total Offences                                                                        4
# Prohibited and regulated weapons and explosives offences                              4
# Fraud, deception and related offences                                                 4
# Miscellaneous offences                                                                4
# Acts intended to cause injury                                                         4
# Public order offences                                                                 4
# Theft and related offences                                                            4
# Sexual assault and related offences                                                   4
# Robbery, extortion and related offences                                               4
# Illicit drug offences                                                                 4
# Homicide and related offences                                                         4
# ...

# %%
# Crime Stats for christchurch
b = pd.read_csv("burglaries_by_mb.csv",usecols=['total','AU2013_code','AU2013_label'])
TOOLS="resize,pan,wheel_zoom,box_zoom,reset,hover"
#c = b.head(10)
welly = b[b['AU2013_label'].isin(['Lambton','Willis Street-Cambridge Terrace','Mt Victoria West','Mt Cook-Wallace Street','Thorndon-Tinakori Road'])]
print(welly['total'].groupby(welly['AU2013_label']).sum().head(5))
cch = b[b['AU2013_label'].isin(['Sydenham','Phillipstown','Linwood','Cathedral Square','Avon Loop'])]
print(cch['total'].groupby(cch['AU2013_label']).sum().head(5))
#print(b[b.AU2013_label == 'Willis Street-Cabridge Terrace'] & )
#print(c.AU2013_code.map(lambda x: unique_saus['SAU'] == x))

#if (c.AU2013_code.map(lambda x: unique_saus['SAU'] == x)):
#    print("Match")

#print(unique_saus['SAU'] == 500100)
#new_b = b.AU2013_code.map(lambda x: unique_saus[unique_saus['SAU'] == x])
#print(new_b.head())
#print(unique_saus)
#print(b.AU2013_label.groupby(b['total']).head(5))
#top_5 = b['total'].sort_values().tail()
#print(top_5)
#top = b['total'].groupby(b['AU2013_label']).sum()
#print(top.sort_values(ascending=False).head(5))
#top = top_5['total'].groupby(b['AU2013_label']).count().head(5)
#print(top)
output_file("lines.html")
chart = Bar(cch['total'].groupby(cch['AU2013_label']).sum().head(5),xlabel='Area', ylabel='Burglaries in 2014')
bokeh.io.show(chart)
#chart1 = Bar(welly['total'].groupby(welly['AU2013_label']).sum().head(5),xlabel='Area', ylabel='Burglaries in 2014')
#bokeh.io.show(chart1)

#show(chart)
# Out:
# AU2013_label
# Lambton                            168
# Mt Cook-Wallace Street             130
# Mt Victoria West                   124
# Thorndon-Tinakori Road              81
# Willis Street-Cambridge Terrace    236
# Name: total, dtype: int64
# AU2013_label
# Avon Loop           178
# Cathedral Square    172
# Linwood             191
# Phillipstown        239
# Sydenham            232
# Name: total, dtype: int64

# %%
# Crime Stats Wellington
output_file("lines1.html")
chart1 = Bar(welly['total'].groupby(welly['AU2013_label']).sum().head(5),xlabel='Area', ylabel='Burglaries in 2014')
bokeh.io.show(chart1)
